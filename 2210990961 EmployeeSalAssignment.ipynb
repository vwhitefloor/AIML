# %%
import pandas as pd

data=pd.read_csv("Salaries.csv")
data
# Out:
# C:\Users\VINAYAK\AppData\Local\Temp\ipykernel_30860\4092087785.py:3: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("Salaries.csv")
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %% [markdown]
# # Display TOP 10 ROWS OF THE DATASET

# %%
data.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %% [markdown]
# # CHECK LAST 10 ROWS OF THE DATASET

# %%
data.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %% [markdown]
# # FIND SHAPE OF OUR DATASET(NUMBER OF ROWS AND NUMBER OF COLUMNS)

# %%
data.shape
# Out:
# (148654, 13)

# %% [markdown]
# # GETTING INFORMATION ABOUT OUR DATASET LIKE TOTAL NUMBER ROWS,TOTAL NUMBER OF COLUMNS,DATATYPES OF EACH COLUMN AND MEMORY REQUIREMENT

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# # CHECK NULL VALUES IN THE DATASET

# %%
data.isnull()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False         False     False    False        False     False
# 148651  False         False     False    False        False     False
# 148652  False         False     False    False        False     False
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %% [markdown]
# # DROP ID,NOTES,AGENCY AND STATUS COLUMNS

# %%
data.drop(['Id', 'Notes', 'Agency', 'Status'], axis=1)
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %% [markdown]
# # FIND OCCURRENCE OF THE EMPLOYEE NAME(TOP5)

# %%
top5_names = data['EmployeeName'].value_counts().head(5)
print(top5_names)
# Out:
# EmployeeName
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: count, dtype: int64

# %% [markdown]
# # FIND THE NUMBER OF UNIQUE JOB TITLES

# %%
data['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# # TOTAL NUMBER OF JOBS TITLES CONTAINS CAPTAIN

# %%
captain_titles_count = data['JobTitle'].str.contains('Captain', case=False).sum()
print("Total number of job titles containing 'Captain':", captain_titles_count)
# Out:
# Total number of job titles containing 'Captain': 552

# %% [markdown]
# # DISPLAY ALL THE EMPLOYEE NAMES FROM FIRE DEPARTMENT

# %%
fire_department_employees = data[data['JobTitle'] == 'Fire']['EmployeeName']
print(fire_department_employees)
# Out:
# Series([], Name: EmployeeName, dtype: object)

# %% [markdown]
# # FIND MINIMUM,MAXIMUM AND AVERGE BASEPAY

# %%
data['BasePay'] = pd.to_numeric(data['BasePay'], errors='coerce')
data['BasePay'].min()
data['BasePay'].max()
data['BasePay'].mean()
# Out:
# 66325.4488404877

# %% [markdown]
# # REPLACE 'NOT PROVIDED' IN  EMPLOYEENAME COLUMN TO NaN

# %%
import numpy as np

data['EmployeeName'] = data['EmployeeName'].replace('NOT PROVIDED', np.nan)

# %% [markdown]
# # drop the rows having more than 5 missing values

# %%
data.dropna(thresh=5)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# # find the job title of ALBERT PARDINI

# %%
albert_pardini_job_title = data[data['EmployeeName'] == 'ALBERT PARDINI']['JobTitle'].iloc[0]
print("Job Title of ALBERT PARDINI:", albert_pardini_job_title)
# Out:
# Job Title of ALBERT PARDINI: CAPTAIN III (POLICE DEPARTMENT)

# %% [markdown]
# # HOW MUCH ALBERT PARDINI MAKE (INCULDE DENEFITS)?

# %%
relevant_columns = ['BasePay', 'OvertimePay', 'OtherPay', 'Benefits']
data[relevant_columns] = data[relevant_columns].apply(pd.to_numeric, errors='coerce')
albert_pardini_data = data[data['EmployeeName'] == 'ALBERT PARDINI']
total_compensation = albert_pardini_data[relevant_columns].sum(axis=1).iloc[0]

print("Total Compensation for ALBERT PARDINI:", total_compensation)
# Out:
# Total Compensation for ALBERT PARDINI: 335279.91

# %% [markdown]
# # DISPLAY NAME OF THE PERSON HAVINNG THE HIGHEST BASEPAY

# %%
data['Basepay'] = pd.to_numeric(data['BasePay'], errors='coerce')
max_basepay_index = data['BasePay'].idxmax()
person_highest_basepay = data.loc[max_basepay_index, 'EmployeeName']

print("Person with the highest base pay:", person_highest_basepay)
# Out:
# Person with the highest base pay: Gregory P Suhr

# %% [markdown]
# # FIND AVERGE BASEPAY OF ALL EMPLOYEE PER YEAR

# %%
data['Year'] = pd.to_datetime(data['Year'], errors='coerce').dt.year
average_basepay_per_year = data.groupby('Year')['BasePay'].mean()
print("Average Base Pay per Year:")
print(average_basepay_per_year)
# Out:
# Average Base Pay per Year:
# Year
# 1970    66325.44884
# Name: BasePay, dtype: float64

# %% [markdown]
# # FIND AVERGE BASEPAY OF ALL EMPLOYEE PER JOB TITLE

# %%
data.groupby('JobTitle')['BasePay'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...

# %% [markdown]
# # FIND AVERGE BASEPAY OF EMPLOYEE HAVIG JOB TITLE ACCOUNTANT

# %%
data[data['JobTitle'] == 'ACCOUNTANT']['BasePay'].mean()
# Out:
# 46643.172

# %% [markdown]
# # FIND TOP5 MOST COMMAN JOBS

# %%
top5_jobs = data['JobTitle'].value_counts().head(5)
print("Top 5 most common jobs:")
print(top5_jobs)
# Out:
# Top 5 most common jobs:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64
